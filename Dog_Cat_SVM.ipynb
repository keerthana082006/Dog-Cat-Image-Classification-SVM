# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-46e1171a-e142-4887-bf2e-45cb81e0e802" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46e1171a-e142-4887-bf2e-45cb81e0e802">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'dogcat.zip', 'sample_data']

# %%
import zipfile

with zipfile.ZipFile('dogcat.zip', 'r') as zip_ref:
    zip_ref.extractall('dataset')

print("Dataset Extracted Successfully")
# Out:
# Dataset Extracted Successfully

# %%
import os

for root, dirs, files in os.walk('dataset'):
    print(root)
# Out:
# dataset
# dataset/cats_and_dogs_filtered
# dataset/cats_and_dogs_filtered/train
# dataset/cats_and_dogs_filtered/train/dogs
# dataset/cats_and_dogs_filtered/train/cats
# dataset/cats_and_dogs_filtered/validation
# dataset/cats_and_dogs_filtered/validation/dogs
# dataset/cats_and_dogs_filtered/validation/cats
# dataset/cats_and_dogs_filtered/cats_and_dogs_filtered
# dataset/cats_and_dogs_filtered/cats_and_dogs_filtered/train
# dataset/cats_and_dogs_filtered/cats_and_dogs_filtered/train/dogs
# dataset/cats_and_dogs_filtered/cats_and_dogs_filtered/train/cats
# dataset/cats_and_dogs_filtered/cats_and_dogs_filtered/validation
# dataset/cats_and_dogs_filtered/cats_and_dogs_filtered/validation/dogs
# dataset/cats_and_dogs_filtered/cats_and_dogs_filtered/validation/cats

# %%
import os
import cv2
import numpy as np

data = []
labels = []

cat_path = "dataset/cats_and_dogs_filtered/train/cats"
dog_path = "dataset/cats_and_dogs_filtered/train/dogs"

# Cats
for img_name in os.listdir(cat_path):
    img = cv2.imread(os.path.join(cat_path, img_name))
    img = cv2.resize(img, (64, 64))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    data.append(img.flatten())
    labels.append(0)

# Dogs
for img_name in os.listdir(dog_path):
    img = cv2.imread(os.path.join(dog_path, img_name))
    img = cv2.resize(img, (64, 64))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    data.append(img.flatten())
    labels.append(1)

data = np.array(data)
labels = np.array(labels)

print(data.shape)
print(labels.shape)
# Out:
# (2000, 4096)
# (2000,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    data,
    labels,
    test_size=0.2,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1600, 4096)
# (400, 4096)

# %%
from sklearn.svm import SVC

svm = SVC(kernel='rbf', gamma='scale')

svm.fit(X_train, y_train)

print("Training Complete")
# Out:
# Training Complete

# %%
from sklearn.metrics import accuracy_score

y_pred = svm.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6075

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.58      0.59       199
#            1       0.60      0.64      0.62       201
#
#     accuracy                           0.61       400
#    macro avg       0.61      0.61      0.61       400
# weighted avg       0.61      0.61      0.61       400
